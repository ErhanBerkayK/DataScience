# %%
first_number=3
second_number=4
print(f'{first_number}+{second_number}={first_number+second_number}')
# Out:
# 3+4=7

# %%
first_word="Merhaba"
second_word="Dunya"
print(f'{first_word} {second_word}')
# Out:
# Merhaba Dunya

# %%
import pandas as pd
pd.read_csv('msleep.csv')
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates           NaN
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia           NaN
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea           NaN
# 80                       Genet     Genetta  carni     Carnivora           NaN
# 81                  Arctic fox      Vulpes  carni     Carnivora           NaN
# 82                     Red fox      Vulpes  carni     Carnivora           NaN
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 0          12.1        NaN          NaN   11.9      NaN   50.000
# 1          17.0        1.8          NaN    7.0  0.01550    0.480
# 2          14.4        2.4          NaN    9.6      NaN    1.350
# 3          14.9        2.3     0.133333    9.1  0.00029    0.019
# 4           4.0        0.7     0.666667   20.0  0.42300  600.000
# ..          ...        ...          ...    ...      ...      ...
# 78          8.9        2.6     0.233333   15.1  0.00250    0.104
# 79          5.2        NaN          NaN   18.8      NaN  173.330
# 80          6.3        1.3          NaN   17.7  0.01750    2.000
# 81         12.5        NaN          NaN   11.5  0.04450    3.380
# 82          9.8        2.4     0.350000   14.2  0.05040    4.230
#
# [83 rows x 11 columns]

# %%
df_animal=pd.read_csv("msleep.csv")
df_animal
# Out:
#                           name       genus   vore         order  conservation  \
# 0                      Cheetah    Acinonyx  carni     Carnivora            lc
# 1                   Owl monkey       Aotus   omni      Primates           NaN
# 2              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 3   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 4                          Cow         Bos  herbi  Artiodactyla  domesticated
# ..                         ...         ...    ...           ...           ...
# 78                  Tree shrew      Tupaia   omni    Scandentia           NaN
# 79        Bottle-nosed dolphin    Tursiops  carni       Cetacea           NaN
# 80                       Genet     Genetta  carni     Carnivora           NaN
# 81                  Arctic fox      Vulpes  carni     Carnivora           NaN
# 82                     Red fox      Vulpes  carni     Carnivora           NaN
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 0          12.1        NaN          NaN   11.9      NaN   50.000
# 1          17.0        1.8          NaN    7.0  0.01550    0.480
# 2          14.4        2.4          NaN    9.6      NaN    1.350
# 3          14.9        2.3     0.133333    9.1  0.00029    0.019
# 4           4.0        0.7     0.666667   20.0  0.42300  600.000
# ..          ...        ...          ...    ...      ...      ...
# 78          8.9        2.6     0.233333   15.1  0.00250    0.104
# 79          5.2        NaN          NaN   18.8      NaN  173.330
# 80          6.3        1.3          NaN   17.7  0.01750    2.000
# 81         12.5        NaN          NaN   11.5  0.04450    3.380
# 82          9.8        2.4     0.350000   14.2  0.05040    4.230
#
# [83 rows x 11 columns]

# %%
df_animal.head(7)
# Out:
#                          name        genus   vore         order  conservation  \
# 0                     Cheetah     Acinonyx  carni     Carnivora            lc
# 1                  Owl monkey        Aotus   omni      Primates           NaN
# 2             Mountain beaver   Aplodontia  herbi      Rodentia            nt
# 3  Greater short-tailed shrew      Blarina   omni  Soricomorpha            lc
# 4                         Cow          Bos  herbi  Artiodactyla  domesticated
# 5            Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 6           Northern fur seal  Callorhinus  carni     Carnivora            vu
#
#    sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 0         12.1        NaN          NaN   11.9      NaN   50.000
# 1         17.0        1.8          NaN    7.0  0.01550    0.480
# 2         14.4        2.4          NaN    9.6      NaN    1.350
# 3         14.9        2.3     0.133333    9.1  0.00029    0.019
# 4          4.0        0.7     0.666667   20.0  0.42300  600.000
# 5         14.4        2.2     0.766667    9.6      NaN    3.850
# 6          8.7        1.4     0.383333   15.3      NaN   20.490

# %%
df_animal.tail(10)
# Out:
#                          name         genus     vore           order  \
# 73                        Pig           Sus     omni    Artiodactyla
# 74        Short-nosed echidna  Tachyglossus  insecti     Monotremata
# 75  Eastern american chipmunk        Tamias    herbi        Rodentia
# 76            Brazilian tapir       Tapirus    herbi  Perissodactyla
# 77                     Tenrec        Tenrec     omni    Afrosoricida
# 78                 Tree shrew        Tupaia     omni      Scandentia
# 79       Bottle-nosed dolphin      Tursiops    carni         Cetacea
# 80                      Genet       Genetta    carni       Carnivora
# 81                 Arctic fox        Vulpes    carni       Carnivora
# 82                    Red fox        Vulpes    carni       Carnivora
#
#     conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 73  domesticated          9.1        2.4     0.500000   14.9   0.1800   86.250
# 74           NaN          8.6        NaN          NaN   15.4   0.0250    4.500
# 75           NaN         15.8        NaN          NaN    8.2      NaN    0.112
# 76            vu          4.4        1.0     0.900000   19.6   0.1690  207.501
# 77           NaN         15.6        2.3          NaN    8.4   0.0026    0.900
# 78           NaN          8.9        2.6     0.233333   15.1   0.0025    0.104
# 79           NaN          5.2        NaN          NaN   18.8      NaN  173.330
# 80           NaN          6.3        1.3          NaN   17.7   0.0175    2.000
# 81           NaN         12.5        NaN          NaN   11.5   0.0445    3.380
# 82           NaN          9.8        2.4     0.350000   14.2   0.0504    4.230

# %%
df_animal.dtypes
# Out:
# name             object
# genus            object
# vore             object
# order            object
# conservation     object
# sleep_total     float64
# sleep_rem       float64
# sleep_cycle     float64
# awake           float64
# brainwt         float64
# bodywt          float64
# dtype: object

# %%
df_animal.shape
# Out:
# (83, 11)

# %%
df_animal.shape[0]
# Out:
# 83

# %%
df_animal.shape[1]
# Out:
# 11

# %%
df_animal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          83 non-null     object
#  1   genus         83 non-null     object
#  2   vore          76 non-null     object
#  3   order         83 non-null     object
#  4   conservation  54 non-null     object
#  5   sleep_total   83 non-null     float64
#  6   sleep_rem     61 non-null     float64
#  7   sleep_cycle   32 non-null     float64
#  8   awake         83 non-null     float64
#  9   brainwt       56 non-null     float64
#  10  bodywt        83 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 7.3+ KB

# %%
df_animal.describe()
# Out:
#        sleep_total  sleep_rem  sleep_cycle      awake    brainwt       bodywt
# count    83.000000  61.000000    32.000000  83.000000  56.000000    83.000000
# mean     10.433735   1.875410     0.439583  13.567470   0.281581   166.136349
# std       4.450357   1.298288     0.358680   4.452085   0.976414   786.839732
# min       1.900000   0.100000     0.116667   4.100000   0.000140     0.005000
# 25%       7.850000   0.900000     0.183333  10.250000   0.002900     0.174000
# 50%      10.100000   1.500000     0.333333  13.900000   0.012400     1.670000
# 75%      13.750000   2.400000     0.579167  16.150000   0.125500    41.750000
# max      19.900000   6.600000     1.500000  22.100000   5.712000  6654.000000

# %%
df_animal.describe().T
# Out:
#              count        mean         std       min        25%        50%  \
# sleep_total   83.0   10.433735    4.450357  1.900000   7.850000  10.100000
# sleep_rem     61.0    1.875410    1.298288  0.100000   0.900000   1.500000
# sleep_cycle   32.0    0.439583    0.358680  0.116667   0.183333   0.333333
# awake         83.0   13.567470    4.452085  4.100000  10.250000  13.900000
# brainwt       56.0    0.281581    0.976414  0.000140   0.002900   0.012400
# bodywt        83.0  166.136349  786.839732  0.005000   0.174000   1.670000
#
#                    75%       max
# sleep_total  13.750000    19.900
# sleep_rem     2.400000     6.600
# sleep_cycle   0.579167     1.500
# awake        16.150000    22.100
# brainwt       0.125500     5.712
# bodywt       41.750000  6654.000

# %%
df_animal.genus
# Out:
# 0       Acinonyx
# 1          Aotus
# 2     Aplodontia
# 3        Blarina
# 4            Bos
#          ...
# 78        Tupaia
# 79      Tursiops
# 80       Genetta
# 81        Vulpes
# 82        Vulpes
# Name: genus, Length: 83, dtype: object

# %%
df_animal["genus"]
# Out:
# 0       Acinonyx
# 1          Aotus
# 2     Aplodontia
# 3        Blarina
# 4            Bos
#          ...
# 78        Tupaia
# 79      Tursiops
# 80       Genetta
# 81        Vulpes
# 82        Vulpes
# Name: genus, Length: 83, dtype: object

# %%
df_animal[["name","genus"]]
# Out:
#                           name       genus
# 0                      Cheetah    Acinonyx
# 1                   Owl monkey       Aotus
# 2              Mountain beaver  Aplodontia
# 3   Greater short-tailed shrew     Blarina
# 4                          Cow         Bos
# ..                         ...         ...
# 78                  Tree shrew      Tupaia
# 79        Bottle-nosed dolphin    Tursiops
# 80                       Genet     Genetta
# 81                  Arctic fox      Vulpes
# 82                     Red fox      Vulpes
#
# [83 rows x 2 columns]

# %%
df_animal["name"].str.len()
# Out:
# 0      7
# 1     10
# 2     15
# 3     26
# 4      3
#       ..
# 78    10
# 79    20
# 80     5
# 81    10
# 82     7
# Name: name, Length: 83, dtype: int64

# %%
df_animal["vore"].value_counts()
# Out:
# vore
# herbi      32
# omni       20
# carni      19
# insecti     5
# Name: count, dtype: int64

# %%
df_animal["vore"]=="herbi"
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
#       ...
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# Name: vore, Length: 83, dtype: bool

# %%
df_animal[df_animal["vore"]=="herbi"]
# Out:
#                               name         genus   vore           order  \
# 2                  Mountain beaver    Aplodontia  herbi        Rodentia
# 4                              Cow           Bos  herbi    Artiodactyla
# 5                 Three-toed sloth      Bradypus  herbi          Pilosa
# 9                         Roe deer     Capreolus  herbi    Artiodactyla
# 10                            Goat         Capri  herbi    Artiodactyla
# 11                      Guinea pig         Cavis  herbi        Rodentia
# 13                      Chinchilla    Chinchilla  herbi        Rodentia
# 18                      Tree hyrax   Dendrohyrax  herbi      Hyracoidea
# 20                  Asian elephant       Elephas  herbi     Proboscidea
# 22                           Horse         Equus  herbi  Perissodactyla
# 23                          Donkey         Equus  herbi  Perissodactyla
# 26       Western american chipmunk      Eutamias  herbi        Rodentia
# 29                         Giraffe       Giraffa  herbi    Artiodactyla
# 32                      Gray hyrax   Heterohyrax  herbi      Hyracoidea
# 34                  Mongoose lemur         Lemur  herbi        Primates
# 35                African elephant     Loxodonta  herbi     Proboscidea
# 38                Mongolian gerbil      Meriones  herbi        Rodentia
# 39                  Golden hamster  Mesocricetus  herbi        Rodentia
# 40                           Vole       Microtus  herbi        Rodentia
# 41                     House mouse           Mus  herbi        Rodentia
# 43            Round-tailed muskrat      Neofiber  herbi        Rodentia
# 45                            Degu       Octodon  herbi        Rodentia
# 47                          Rabbit   Oryctolagus  herbi      Lagomorpha
# 48                           Sheep          Ovis  herbi    Artiodactyla
# 60                         Potoroo      Potorous  herbi   Diprotodontia
# 63                  Laboratory rat        Rattus  herbi        Rodentia
# 67                      Cotton rat      Sigmodon  herbi        Rodentia
# 69          Arctic ground squirrel  Spermophilus  herbi        Rodentia
# 70  Thirteen-lined ground squirrel  Spermophilus  herbi        Rodentia
# 71  Golden-mantled ground squirrel  Spermophilus  herbi        Rodentia
# 75       Eastern american chipmunk        Tamias  herbi        Rodentia
# 76                 Brazilian tapir       Tapirus  herbi  Perissodactyla
#
#     conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt  \
# 2             nt         14.4        2.4          NaN    9.6      NaN
# 4   domesticated          4.0        0.7     0.666667   20.0  0.42300
# 5            NaN         14.4        2.2     0.766667    9.6      NaN
# 9             lc          3.0        NaN          NaN   21.0  0.09820
# 10            lc          5.3        0.6          NaN   18.7  0.11500
# 11  domesticated          9.4        0.8     0.216667   14.6  0.00550
# 13  domesticated         12.5        1.5     0.116667   11.5  0.00640
# 18            lc          5.3        0.5          NaN   18.7  0.01230
# 20            en          3.9        NaN          NaN   20.1  4.60300
# 22  domesticated          2.9        0.6     1.000000   21.1  0.65500
# 23  domesticated          3.1        0.4          NaN   20.9  0.41900
# 26           NaN         14.9        NaN          NaN    9.1      NaN
# 29            cd          1.9        0.4          NaN   22.1      NaN
# 32            lc          6.3        0.6          NaN   17.7  0.01227
# 34            vu          9.5        0.9          NaN   14.5      NaN
# 35            vu          3.3        NaN          NaN   20.7  5.71200
# 38            lc         14.2        1.9          NaN    9.8      NaN
# 39            en         14.3        3.1     0.200000    9.7  0.00100
# 40           NaN         12.8        NaN          NaN   11.2      NaN
# 41            nt         12.5        1.4     0.183333   11.5  0.00040
# 43            nt         14.6        NaN          NaN    9.4      NaN
# 45            lc          7.7        0.9          NaN   16.3      NaN
# 47  domesticated          8.4        0.9     0.416667   15.6  0.01210
# 48  domesticated          3.8        0.6          NaN   20.2  0.17500
# 60           NaN         11.1        1.5          NaN   12.9      NaN
# 63            lc         13.0        2.4     0.183333   11.0  0.00190
# 67           NaN         11.3        1.1     0.150000   12.7  0.00118
# 69            lc         16.6        NaN          NaN    7.4  0.00570
# 70            lc         13.8        3.4     0.216667   10.2  0.00400
# 71            lc         15.9        3.0          NaN    8.1      NaN
# 75           NaN         15.8        NaN          NaN    8.2      NaN
# 76            vu          4.4        1.0     0.900000   19.6  0.16900
#
#       bodywt
# 2      1.350
# 4    600.000
# 5      3.850
# 9     14.800
# 10    33.500
# 11     0.728
# 13     0.420
# 18     2.950
# 20  2547.000
# 22   521.000
# 23   187.000
# 26     0.071
# 29   899.995
# 32     2.625
# 34     1.670
# 35  6654.000
# 38     0.053
# 39     0.120
# 40     0.035
# 41     0.022
# 43     0.266
# 45     0.210
# 47     2.500
# 48    55.500
# 60     1.100
# 63     0.320
# 67     0.148
# 69     0.920
# 70     0.101
# 71     0.205
# 75     0.112
# 76   207.501

# %%
df_animal[(df_animal["vore"]=="herbi") & (df_animal["sleep_total"]>9)]
# Out:
#                               name         genus   vore          order  \
# 2                  Mountain beaver    Aplodontia  herbi       Rodentia
# 5                 Three-toed sloth      Bradypus  herbi         Pilosa
# 11                      Guinea pig         Cavis  herbi       Rodentia
# 13                      Chinchilla    Chinchilla  herbi       Rodentia
# 26       Western american chipmunk      Eutamias  herbi       Rodentia
# 34                  Mongoose lemur         Lemur  herbi       Primates
# 38                Mongolian gerbil      Meriones  herbi       Rodentia
# 39                  Golden hamster  Mesocricetus  herbi       Rodentia
# 40                           Vole       Microtus  herbi       Rodentia
# 41                     House mouse           Mus  herbi       Rodentia
# 43            Round-tailed muskrat      Neofiber  herbi       Rodentia
# 60                         Potoroo      Potorous  herbi  Diprotodontia
# 63                  Laboratory rat        Rattus  herbi       Rodentia
# 67                      Cotton rat      Sigmodon  herbi       Rodentia
# 69          Arctic ground squirrel  Spermophilus  herbi       Rodentia
# 70  Thirteen-lined ground squirrel  Spermophilus  herbi       Rodentia
# 71  Golden-mantled ground squirrel  Spermophilus  herbi       Rodentia
# 75       Eastern american chipmunk        Tamias  herbi       Rodentia
#
#     conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# 2             nt         14.4        2.4          NaN    9.6      NaN   1.350
# 5            NaN         14.4        2.2     0.766667    9.6      NaN   3.850
# 11  domesticated          9.4        0.8     0.216667   14.6  0.00550   0.728
# 13  domesticated         12.5        1.5     0.116667   11.5  0.00640   0.420
# 26           NaN         14.9        NaN          NaN    9.1      NaN   0.071
# 34            vu          9.5        0.9          NaN   14.5      NaN   1.670
# 38            lc         14.2        1.9          NaN    9.8      NaN   0.053
# 39            en         14.3        3.1     0.200000    9.7  0.00100   0.120
# 40           NaN         12.8        NaN          NaN   11.2      NaN   0.035
# 41            nt         12.5        1.4     0.183333   11.5  0.00040   0.022
# 43            nt         14.6        NaN          NaN    9.4      NaN   0.266
# 60           NaN         11.1        1.5          NaN   12.9      NaN   1.100
# 63            lc         13.0        2.4     0.183333   11.0  0.00190   0.320
# 67           NaN         11.3        1.1     0.150000   12.7  0.00118   0.148
# 69            lc         16.6        NaN          NaN    7.4  0.00570   0.920
# 70            lc         13.8        3.4     0.216667   10.2  0.00400   0.101
# 71            lc         15.9        3.0          NaN    8.1      NaN   0.205
# 75           NaN         15.8        NaN          NaN    8.2      NaN   0.112

# %%
df_animal[(df_animal["genus"]=="Spermophilus") & (df_animal["awake"]<10)]
# Out:
#                               name         genus   vore     order  \
# 69          Arctic ground squirrel  Spermophilus  herbi  Rodentia
# 71  Golden-mantled ground squirrel  Spermophilus  herbi  Rodentia
#
#    conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# 69           lc         16.6        NaN          NaN    7.4   0.0057   0.920
# 71           lc         15.9        3.0          NaN    8.1      NaN   0.205

# %%
df_animal.groupby("vore")["vore"].count() # !!!
# Out:
# vore
# carni      19
# herbi      32
# insecti     5
# omni       20
# Name: vore, dtype: int64

# %%
df_animal.groupby("vore")["vore"].count()
# Out:
# vore
# carni      19
# herbi      32
# insecti     5
# omni       20
# Name: vore, dtype: int64

# %%
df_animal.groupby("vore")["vore"].count()
# Out:
# vore
# carni      19
# herbi      32
# insecti     5
# omni       20
# Name: vore, dtype: int64

# %%
df_animal["vore"].unique()
# Out:
# array(['carni', 'omni', 'herbi', nan, 'insecti'], dtype=object)

# %%
df_animal["vore"].nunique() # Benzersiz değerlerin sayısını verir.
# Out:
# 4

# %%
df_animal["vore"].nunique(dropna=False) # Benzersiz değerlerin sayısını NaN'ı da katarak verir.
# Out:
# 5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df_animal.sleep_total) # Histogram grafiği çizer.
plt.title("Distribution of Sleep Times of Various Mammals")
plt.xlabel("Hours of Sleep")
plt.ylabel("y label")
# Out:
# Text(0, 0.5, 'y label')

# %%
import numpy as np
np.mean(df_animal.sleep_total)
# Out:
# 10.433734939759034

# %%
np.median(df_animal.sleep_total)
# Out:
# 10.1

# %%
import statistics as stat
stat.mode(df_animal.vore)
# Out:
# 'herbi'
